# %%
import sqlite3
from smolagents import CodeAgent, DuckDuckGoSearchTool, LiteLLMModel
from dotenv import load_dotenv
import os
import json
import random

load_dotenv()
api_key = os.getenv("GROQ_API_KEY")

search_tool = DuckDuckGoSearchTool()

# Define the agent
model = LiteLLMModel(
    "llama-3.3-70b-versatile",
    api_base="https://api.groq.com/openai/v1",
    api_key=api_key
)

# model = LiteLLMModel(
#     model_id="anthropic/claude-3-5-sonnet-20240620",
#     # api_base="https://api.anthropic.com/v1",
#     api_key=api_key
# )
model.flatten_messages_as_text = True

agent = CodeAgent(
    tools=[search_tool],
    model=model,
    add_base_tools=False,
    verbosity_level=2
)


# Define the function to choose the best algorithm
def choose_best_algorithm(train_db_file="../train_mTSP.sqlite3", test_db_file="../test_mTSP.sqlite3"):

    conn_train = sqlite3.connect(train_db_file)
    cursor_train = conn_train.cursor()

    # Select instances from the training database
    cursor_train.execute("""
        SELECT instance_id, nr_cities, nr_salesmen, average_distance, stddev_distance, density, salesmen_ratio, 
               bounding_box_area, aspect_ratio, spread, cluster_compactness, mst_total_length, entropy_distance_matrix 
        FROM instances 
    """)
    train_instances = cursor_train.fetchall()
    train_instances_with_columns = [
        {
            "instance_id": row[0], 
            "nr_cities": row[1], 
            "nr_salesmen": row[2],
            "average_distance": row[3],
            "stddev_distance": row[4],
            "density": row[5],
            "salesmen_ratio": row[6],
            "bounding_box_area": row[7],
            "aspect_ratio": row[8],
            "spread": row[9],
            "cluster_compactness": row[10],
            "mst_total_length": row[11],
            "entropy_distance_matrix": row[12]
        } for row in train_instances
    ]

    # Select algorithms from the training database
    cursor_train.execute("""
        SELECT instance_id, strategy, total_cost, normalized_cost, time_taken, distance_gap, efficiency 
        FROM algorithms 
        WHERE instance_id IN (SELECT instance_id FROM instances)
    """)
    train_algorithms_data = cursor_train.fetchall()
    train_algorithms_with_columns = [
        {
            "instance_id": row[0],
            "strategy": row[1],
            "total_cost": row[2],
            "normalized_cost": row[3],
            "time_taken": row[4],
            "distance_gap": row[5],
            "efficiency": row[6],
        }
        for row in train_algorithms_data
    ]


    conn_train.close()
    conn_test = sqlite3.connect(test_db_file)
    cursor_test = conn_test.cursor()

    # Select instances from the test database
    cursor_test.execute("""
        SELECT instance_id, nr_cities, nr_salesmen, average_distance, stddev_distance, density, salesmen_ratio, 
               bounding_box_area, aspect_ratio, spread, cluster_compactness, mst_total_length, entropy_distance_matrix 
        FROM instances 
    """)
    test_instances = cursor_test.fetchall()
    test_instances_with_columns = [
        {
            "instance_id": row[0], 
            "nr_cities": row[1], 
            "nr_salesmen": row[2],
            "average_distance": row[3],
            "stddev_distance": row[4],
            "density": row[5],
            "salesmen_ratio": row[6],
            "bounding_box_area": row[7],
            "aspect_ratio": row[8],
            "spread": row[9],
            "cluster_compactness": row[10],
            "mst_total_length": row[11],
            "entropy_distance_matrix": row[12]
        } for row in test_instances
    ]

    # test_instances_with_columns = test_instances_with_columns[:5]


    conn_test.close()

    # sample a subset of training instances
    nr_train = len(train_instances_with_columns)
    sample_size = max(1, nr_train // 20)
    sampled_instances = random.sample(train_instances_with_columns, sample_size)
    sampled_ids = set(inst["instance_id"] for inst in sampled_instances)

    # filter algorithms to only include those that match the sampled instances
    sampled_algorithms = [alg for alg in train_algorithms_with_columns if alg["instance_id"] in sampled_ids]


    # Prepare the data for the agent
    data = {
        "train_instances": sampled_instances,
        "train_algorithms": sampled_algorithms,
        "test_instances": test_instances_with_columns,
    }
    data_str = json.dumps(data, indent=4)

    # {data_str}

    # Task for the agent
    task = f"""
    You are an AI agent tasked with selecting the best algorithm for solving each instance of the mTSP problem.
    Below is the data from the training instances and their results for different strategies:

    {data_str}

    To evaluate each strategy, use the following composite score formula (lower is better):

    1. For each instance, normalize 'time_taken' and 'distance_gap' among all strategies for that instance.
    2. Compute a bonus/penalty for each strategy:
       - Greedy: -0.02
       - KMeans Greedy: 0.0
       - Branch and Cut: +0.2 if nr_cities > 40, else -0.3
       - Ant Colony: -0.1
    3. The composite score is:
       composite_score = normalized_cost * 0.65 + time_taken_norm * 0.25 + distance_gap_norm * 0.1 + strat_bonus

    Your task is to:
    1. Analyze the performance of each strategy (Greedy, Branch and Cut, Ant Colony, KMeans-Greedy) on the training instances.
    2. Based on this analysis, recommend the best strategy for each test instance.
    3. Justify your recommendations based on the training data.
    4. Consider the following performance metrics: total cost, normalized_cost, time taken, efficiency, and distance gap. The total cost is the most important metric, followed by normalized_cost and efficiency. Time taken is less important, but it should be considered for strategies that are computationally expensive.
    5. Take into account that Branch and Cut and Ant Colony are more computationally expensive, while Greedy and KMeans-Greedy are faster but may not always yield the best results.
    6. Branch and Cut and Ant Colony have a 20 seconds time limit, so they may output a weaker solution if the time limit is reached or even no solution at all.

    Output your recommendations in the following format as in a CSV file:
    instance_id,predicted_algorithm
    where:
    - instance_id is the ID of the test instance
    - predicted_algorithm is the algorithm you recommend for that instance 
    """

    response = agent.run(task)
    print(response)

choose_best_algorithm(train_db_file="../train_mTSP.sqlite3", test_db_file="../test_mTSP.sqlite3")
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ You are an AI agent tasked with selecting the best algorithm for solving each instance of the mTSP problem.     │
# │     Below is the data from the training instances and their results for different strategies:                   │
# │                                                                                                                 │
# │     {                                                                                                           │
# │     "train_instances": [                                                                                        │
# │         {                                                                                                       │
# │             "instance_id": 733,                                                                                 │
# │             "nr_cities": 70,                                                                                    │
# │             "nr_salesmen": 3,                                                                                   │
# │             "average_distance": 52.02767378185998,                                                              │
# │             "stddev_distance": 24.62586104232115,                                                               │
# │             "density": 0.0052553205840262605,                                                                   │
# │             "salesmen_ratio": 0.04285714285714286,                                                              │
# │             "bounding_box_area": 9900.0,                                                                        │
# │             "aspect_ratio": 1.0101010101010102,                                                                 │
# │             "spread": 2.5020684836852327,                                                                       │
# │             "cluster_compactness": 0.7432524825979997,                                                          │
# │             "mst_total_length": 627.0455515523668,                                                              │
# │             "entropy_distance_matrix": 2.726876830726254                                                        │
# │         },                                                                                                      │
# │         {                                                                                                       │
# │             "instance_id": 313,                                                                                 │
# │             "nr_cities": 30,                                                                                    │
# │             "nr_salesmen": 3,                                                                                   │
# │             "average_distance": 6.201474309196723,                                                              │
# │             "stddev_distance": 2.870277092184906,                                                               │
# │             "density": 0.06201474309196722,                                                                     │
# │             "salesmen_ratio": 0.1,                                                                              │
# │             "bounding_box_area": 100.0,                                                                         │
# │             "aspect_ratio": 1.0,                                                                                │
# │             "spread": 2.169423491301435,                                                                        │
# │             "cluster_compactness": 0.20671581030655742,                                                         │
# │             "mst_total_length": 47.49789859063726,                                                              │
# │             "entropy_distance_matrix": 2.778513073656692                                                        │
# │         },                                                                                                      │
# │         {                                                                                                       │
# │             "instance_id": 397,                                                                                 │
# │             "nr_cities": 30,                                                                                    │
# │             "nr_salesmen": 2,                                                                                   │
# │             "average_distance": 10.712077731283562,                                                             │
# │             "stddev_distance": 4.910794926279329,                                                               │
# │             "density": 0.03150611097436342,                                                                     │
# │             "salesmen_ratio": 0.06666666666666667,                                                              │
# │             "bounding_box_area": 340.0,                                                                         │
# │             "aspect_ratio": 0.85,                                                                               │
# │             "spread": 2.3188297657892445,                                                                       │
# │             "cluster_compactness": 0.3570692577094521,                                                          │
# │             "mst_total_length": 85.1131996487342,                                                               │
# │             "entropy_distance_matrix": 2.764573220661116                                                        │
# │         },                                                                                                      │
# │         {                                                                                                       │
# │             "instance_id": 384,                                                                                 │
# │             "nr_cities": 30,                                                                                    │
# │             "nr_salesmen": 2,                                                                                   │
# │             "average_distance": 10.638446463606018,                                                             │
# │             "stddev_distance": 4.943314684176472,                                                               │
# │             "density": 0.026596116159015044,                                                                    │
# │             "salesmen_ratio": 0.06666666666666667,                                                              │
# │             "bounding_box_area": 400.0,                                                                         │
# │             "aspect_ratio": 1.0,                                                                                │
# │             "spread": 2.1123577705749934,                                                                       │
# │             "cluster_compactness": 0.3546148821202006,                                                          │
# │             "mst_total_length": 81.6864094808526,                                                               │
# │             "entropy_distance_matrix": 2.8796112524871678                                                       │
# │         },                                                                                                      │
# │         {                                                                                                       │
# │             "instance_id": 943,                                                                                 │
# │             "nr_cities": 30,                                                                                    │
# │             "nr_salesmen": 5,                                                                                   │
# │             "average_distance": 508.4544502712773,                                                              │
# │             "stddev_distance": 234.20187725797788,                                                              │
# │             "density": 0.0005675601659536952,                                                                   │
# │             "salesmen_ratio": 0.16666666666666666,                                                              │
# │             "bounding_box_area": 895860.0,                                                                      │
# │             "aspect_ratio": 0.9968354430379747,                                                                 │
# │             "spread": 2.263774195274925,                                                                        │
# │             "cluster_compactness": 16.948481675709242,                                                          │
# │             "mst_total_length": 3985.9950874774645,                                                             │
# │             "entropy_distance_matrix": 2.7998748099491166                                                       │
# │         },                                                                                                      │
# │         {                                                                                                       │
# │             "instance_id": 399,                                                                                 │
# │             "nr_cities": 30,                                                                                    │
# │             "nr_salesmen": 2,                                                                                   │
# │             "average_distance": 10.666743544242836,                                                             │
# │             "stddev_distance": 5.373085196322943,                                                               │
# │             "density": 0.02666685886060709,                                                                     │
# │             "salesmen_ratio": 0.06666666666666667,                                                              │
# │             "bounding_box_area": 400.0,                                                                         │
# │             "aspect_ratio": 1.0,                                                                                │
# │             "spread": 2.5225363282189415,                                                                       │
# │             "cluster_compactness": 0.35555811814142785,                                                         │
# │             "mst_total_length": 79.05025786603173,                                                              │
# │             "entropy_distance_matrix": 2.7444866943355795                                                       │
# │         },                                                                                                      │
# │         {                                                                                                       │
# │             "instance_id": 902,                                                                                 │
# │             "nr_cities": 30,                                                                                    │
# │             "nr_salesmen": 5,                                                                                   │
# │             "average_distance": 547.0898368157422,                                                              │
# │             "stddev_distance": 260.2897986286234,                                                               │
# │             "density": 0.0005882193072148166,                                                                   │
# │             "salesmen_ratio": 0.16666666666666666,                                                              │
# │             "bounding_box_area": 930078.0,                                                                      │
# │             "aspect_ratio": 1.028391167192429,                                                                  │
# │             "spread": 2.127811318931088,                                                                        │
# │             "cluster_compactness": 18.23632789385807,                                                           │
# │             "mst_total_length": 3794.8141544253076,                                                             │
# │             "entropy_distance_matrix": 2.859748259627966                                                        │
# │         },                                                                                                      │
# │         {                                                                                                       │
# │             "instance_id": 87,                                                                                  │
# │             "nr_cities": 20,                                                                                    │
# │             "nr_salesmen": 6,                                                                                   │
# │             "average_distance": 54.3081567233998,                                                               │
# │             "stddev_distance": 25.148990682615203,                                                              │
# │             "density": 0.006226571511511098,                                                                    │
# │             "salesmen_ratio": 0.3,                                                                              │
# │             "bounding_box_area": 8722.0,                                                                        │
# │             "aspect_ratio": 0.9081632653061225,                                                                 │
# │             "spread": 2.3294275563663094,                                                                       │
# │             "cluster_compactness": 2.71540783616999,                                                            │
# │             "mst_total_length": 321.8996396976933,                                                              │
# │             "entropy_distance_matrix": 2.7518230876408616                                                       │
# │         },                                                                                                      │
# │         {                                                                                                       │
# │             "instance_id": 435,                                                                                 │
# │             "nr_cities": 45,                                                                                    │
# │             "nr_salesmen": 2,                                                                                   │
# │             "average_distance": 50.1497937639808,                                                               │
# │             "stddev_distance": 23.703138297287296,                                                              │
# │             "density": 0.005169016054832076,                                                                    │
# │             "salesmen_ratio": 0.044444444444444446,                                                             │
# │             "bounding_box_area": 9702.0,                                                                        │
# │             "aspect_ratio": 0.98989898989899,                                                                   │
# │             "spread": 2.367187040741404,                                                                        │
# │             "cluster_compactness": 1.1144398614217956,                                                          │
# │             "mst_total_length": 464.77785453236334,                                                             │
# │             "entropy_distance_matrix": 2.780720040892273                                                        │
# │         },                                                                                                      │
# │         {                                                                                                       │
# │             "instance_id": 213,                                                                                 │
# │             "nr_cities": 40,                                                                                    │
# │             "nr_salesmen": 2,                                                                                   │
# │             "average_distance": 538.7899429192829,                                                              │
# │             "stddev_distance": 256.1487655483888,                                                               │
# │             "density": 0.0005933234916872406,                                                                   │
# │             "salesmen_ratio": 0.05,                                                                             │
# │             "bounding_box_area": 908088.0,                                                                      │
# │             "aspect_ratio": 0.9771784232365145,                                                                 │
# │             "spread": 2.049823496014898,                                                                        │
# │             "cluster_compactness": 13.469748572982073,                                                          │
# │             "mst_total_length": 4473.238252140915,                                                              │
# │             "entropy_distance_matrix": 2.89494888972136                                                         │
# │         },                                                                                                      │
# │         {                                                                                                       │
# │             "instance_id": 548,                                                                                 │
# │             "nr_cities": 20,                                                                                    │
# │             "nr_salesmen": 8,                                                                                   │
# │             "average_distance": 59.604269467473245,                                                             │
# │             "stddev_distance": 26.66489781594054,                                                               │
# │             "density": 0.00633750871530816,                                                                     │
# │             "salesmen_ratio": 0.4,                                                                              │
# │             "bounding_box_area": 9405.0,                                                                        │
# │             "aspect_ratio": 0.9595959595959596,                                                                 │
# │             "spread": 2.1375124233103846,                                                                       │
# │             "cluster_compactness": 2.980213473373662,                                                           │
# │             "mst_total_length": 366.6885535156617,                                                              │
# │             "entropy_distance_matrix": 2.851634117346305                                                        │
# │         },                                                                                                      │
# │         {                                                                                                       │
# │             "instance_id": 1000,                                                                                │
# │             "nr_cities": 30,                                                                                    │
# │             "nr_salesmen": 10,                                                                                  │
# │             "average_distance": 494.39756806520484,                                                             │
# │             "stddev_distance": 232.53162939631636,                                                              │
# │             "density": 0.0005858957328771661,                                                                   │
# │             "salesmen_ratio": 0.3333333333333333,                                                               │
# │             "bounding_box_area": 843832.0,                                                                      │
# │             "aspect_ratio": 1.0605381165919283,                                                                 │
# │             "spread": 2.1998269147396026,                                                                       │
# │             "cluster_compactness": 16.479918935506827,                                                          │
# │             "mst_total_length": 3777.7487316375777,                                                             │
# │             "entropy_distance_matrix": 2.8442981816123587                                                       │
# │         },                                                                                                      │
# │         {                                                                                                       │
# │             "instance_id": 676,                                                                                 │
# │             "nr_cities": 50,                                                                                    │
# │             "nr_salesmen": 9,                                                                                   │
# │             "average_distance": 52.74141967898025,                                                              │
# │             "stddev_distance": 24.805263183812862,                                                              │
# │             "density": 0.005436138907336657,                                                                    │
# │             "salesmen_ratio": 0.18,                                                                             │
# │             "bounding_box_area": 9702.0,                                                                        │
# │             "aspect_ratio": 1.010204081632653,                                                                  │
# │             "spread": 2.440230185856419,                                                                        │
# │             "cluster_compactness": 1.054828393579605,                                                           │
# │             "mst_total_length": 483.8158651393735,                                                              │
# │             "entropy_distance_matrix": 2.7467857264365554                                                       │
# │         },                                                                                                      │
# │         {                                                                                                       │
# │             "instance_id": 549,                                                                                 │
# │             "nr_cities": 20,                                                                                    │
# │             "nr_salesmen": 8,                                                                                   │
# │             "average_distance": 45.22415196240616,                                                              │
# │             "stddev_distance": 21.15486847592239,                                                               │
# │             "density": 0.006775153852045867,                                                                    │
# │             "salesmen_ratio": 0.4,                                                                              │
# │             "bounding_box_area": 6675.0,                                                                        │
# │             "aspect_ratio": 1.1866666666666668,                                                                 │
# │             "spread": 2.2451111050393795,                                                                       │
# │             "cluster_compactness": 2.261207598120308,                                                           │
# │             "mst_total_length": 269.8040904439518,                                                              │
# │             "entropy_distance_matrix": 2.7841840667522737                                                       │
# │         },                                                                                                      │
# │         {                                                                                                       │
# │             "instance_id": 392,                                                                                 │
# │             "nr_cities": 30,                                                                                    │
# │             "nr_salesmen": 2,                                                                                   │
# │             "average_distance": 10.745159087808664,                                                             │
# │             "stddev_distance": 5.061731528850153,                                                               │
# │             "density": 0.02827673444160175,                                                                     │
# │             "salesmen_ratio": 0.06666666666666667,                                                              │
# │             "bounding_box_area": 380.0,                                                                         │
# │             "aspect_ratio": 0.95,                                                                               │
# │             "spread": 2.2720102170628858,                                                                       │
# │             "cluster_compactness": 0.35817196959362213,                                                         │
# │             "mst_total_length": 82.42123059167196,                                                              │
# │             "entropy_distance_matrix": 2.8111502043521748                                                       │
# │         },                                                                                                      │
# │         {                                                                                                       │
# │             "instance_id": 149,                                                                                 │
# │             "nr_cities": 50,                                                                                    │
# │             "nr_salesmen": 3,                                                                                   │
# │             "average_distance": 51.28760838558936,                                                              │
# │             "stddev_distance": 23.874410999985425,                                                              │
# │             "density": 0.005514796600601006,                                                                    │
# │             "salesmen_ratio": 0.06,                                                                             │
# │             "bounding_box_area": 9300.0,                                                                        │
# │             "aspect_ratio": 1.075268817204301,                                                                  │
# │             "spread": 2.248352422610232,                                                                        │
# │             "cluster_compactness": 1.0257521677117871,                                                          │
# │             "mst_total_length": 488.22632677348827,                                                             │
# │             "entropy_distance_matrix": 2.8078079814741224                                                       │
# │         },                                                                                                      │
# │         {                                                                                                       │
# │             "instance_id": 644,                                                                                 │
# │             "nr_cities": 50,                                                                                    │
# │             "nr_salesmen": 10,                                                                                  │
# │             "average_distance": 54.34487895310504,                                                              │
# │             "stddev_distance": 25.61281109828973,                                                               │
# │             "density": 0.005958868306261517,                                                                    │
# │             "salesmen_ratio": 0.2,                                                                              │
# │             "bounding_box_area": 9120.0,                                                                        │
# │             "aspect_ratio": 1.0105263157894737,                                                                 │
# │             "spread": 2.267731686924473,                                                                        │
# │             "cluster_compactness": 1.0868975790621007,                                                          │
# │             "mst_total_length": 497.9464368263554,                                                              │
# │             "entropy_distance_matrix": 2.817021228568908                                                        │
# │         },                                                                                                      │
# │         {                                                                                                       │
# │             "instance_id": 1031,                                                                                │
# │             "nr_cities": 150,                                                                                   │
# │             "nr_salesmen": 2,                                                                                   │
# │             "average_distance": 102.72590403465519,                                                             │
# │             "stddev_distance": 48.62198228408836,                                                               │
# │             "density": 0.002620358238773951,                                                                    │
# │             "salesmen_ratio": 0.013333333333333334,                                                             │
# │             "bounding_box_area": 39203.0,                                                                       │
# │             "aspect_ratio": 1.0101522842639594,                                                                 │
# │             "spread": 2.582837623322194,                                                                        │
# │             "cluster_compactness": 0.6848393602310345,                                                          │
# │             "mst_total_length": 1678.0879438734023,                                                             │
# │             "entropy_distance_matrix": 2.6890239730995456                                                       │
# │         },                                                                                                      │
# │         {                                                                                                       │
# │             "instance_id": 777,                                                                                 │
# │             "nr_cities": 70,                                                                                    │
# │             "nr_salesmen": 2,                                                                                   │
# │             "average_distance": 51.714034248227,                                                                │
# │             "stddev_distance": 24.376703052562963,                                                              │
# │             "density": 0.005385195693869312,                                                                    │
# │             "salesmen_ratio": 0.02857142857142857,                                                              │
# │             "bounding_box_area": 9603.0,                                                                        │
# │             "aspect_ratio": 0.9797979797979798,                                                                 │
# │             "spread": 2.288406316632504,                                                                        │
# │             "cluster_compactness": 0.7387719178318143,                                                          │
# │             "mst_total_length": 543.2325966999881,                                                              │
# │             "entropy_distance_matrix": 2.8017480426792076                                                       │
# │         },                                                                                                      │
# │         {                                                                                                       │
# │             "instance_id": 324,                                                                                 │
# │             "nr_cities": 30,                                                                                    │
# │             "nr_salesmen": 3,                                                                                   │
# │             "average_distance": 5.860904148127758,                                                              │
# │             "stddev_distance": 2.649876521125381,                                                               │
# │             "density": 0.058609041481277574,                                                                    │
# │             "salesmen_ratio": 0.1,                                                                              │
# │             "bounding_box_area": 100.0,                                                                         │
# │             "aspect_ratio": 1.0,                                                                                │
# │             "spread": 2.2954861071002868,                                                                       │
# │             "cluster_compactness": 0.1953634716042586,                                                          │
# │             "mst_total_length": 49.1377572167371,                                                               │
# │             "entropy_distance_matrix": 2.734596398750748                                                        │
# │         },                                                                                                      │
# │         {                                                                                                       │
# │             "instance_id": 278,                                                                                 │
# │             "nr_cities": 40,                                                                                    │
# │             "nr_salesmen": 3,                                                                                   │
# │             "average_distance": 595.6364456829616,                                                              │
# │             "stddev_distance": 277.2902066797708,                                                               │
# │             "density": 0.0006445570355685428,                                                                   │
# │             "salesmen_ratio": 0.075,                                                                            │
# │             "bounding_box_area": 924102.0,                                                                      │
# │             "aspect_ratio": 0.9602446483180428,                                                                 │
# │             "spread": 2.0803203233044334,                                                                       │
# │             "cluster_compactness": 14.89091114207404,                                                           │
# │             "mst_total_length": 4520.6322259944645,                                                             │
# │             "entropy_distance_matrix": 2.8580430198771736                                                       │
# │         },                                                                                                      │
# │         {                                                                                                       │
# │             "instance_id": 1075,                                                                                │
# │             "nr_cities": 100,                                                                                   │
# │             "nr_salesmen": 10,                                                                                  │
# │             "average_distance": 146.3051936349857,                                                              │
# │             "stddev_distance": 68.96281835474404,                                                               │
# │             "density": 0.0017220479476810935,                                                                   │
# │             "salesmen_ratio": 0.1,                                                                              │
# │             "bounding_box_area": 84960.0,                                                                       │
# │             "aspect_ratio": 0.976271186440678,                                                                  │
# │             "spread": 2.6681481570237313,                                                                       │
# │             "cluster_compactness": 1.463051936349857,                                                           │
# │             "mst_total_length": 2035.0759716096152,                                                             │
# │             "entropy_distance_matrix": 2.6576591801547833                                                       │
# │         },                                                                                                      │
# │         {                                                                                                       │
# │             "instance_id": 1035,                                                                                │
# │             "nr_cities": 150,                                                                                   │
# │             "nr_salesmen": 2,                                                                                   │
# │             "average_distance": 109.64787548530246,                                                             │
# │             "stddev_distance": 52.08186629435656,                                                               │
# │             "density": 0.0028256120470378163,                                                                   │
# │             "salesmen_ratio": 0.013333333333333334,                                                             │
# │             "bounding_box_area": 38805.0,                                                                       │
# │             "aspect_ratio": 1.0205128205128204,                                                                 │
# │             "spread": 2.4961275775288674,                                                                       │
# │             "cluster_compactness": 0.7309858365686831,                                                          │
# │             "mst_total_length": 1681.239539565498,                                                              │
# │             "entropy_distance_matrix": 2.727980981950657                                                        │
# │         },                                                                                                      │
# │         {                                                                                                       │
# │             "instance_id": 877,                                                                                 │
# │             "nr_cities": 40,                                                                                    │
# │             "nr_salesmen": 4,                                                                                   │
# │             "average_distance": 51.60412581244538,                                                              │
# │             "stddev_distance": 24.875388054071113,                                                              │
# │             "density": 0.00554525314984369,                                                                     │
# │             "salesmen_ratio": 0.1,                                                                              │
# │             "bounding_box_area": 9306.0,                                                                        │
# │             "aspect_ratio": 1.053191489361702,                                                                  │
# │             "spread": 2.604777402584252,                                                                        │
# │             "cluster_compactness": 1.2901031453111345,                                                          │
# │             "mst_total_length": 433.91178414770485,                                                             │
# │             "entropy_distance_matrix": 2.6917542419886784                                                       │
# │         },                                                                                                      │
# │         {                                                                                                       │
# │             "instance_id": 305,                                                                                 │
# │             "nr_cities": 30,                                                                                    │
# │             "nr_salesmen": 3,                                                                                   │
# │             "average_distance": 5.764671420144141,                                                              │
# │             "stddev_distance": 2.603298977895348,                                                               │
# │             "density": 0.05764671420144141,                                                                     │
# │             "salesmen_ratio": 0.1,                                                                              │
# │             "bounding_box_area": 100.0,                                                                         │
# │             "aspect_ratio": 1.0,                                                                                │
# │             "spread": 2.3338058783474103,                                                                       │
# │             "cluster_compactness": 0.1921557140048047,                                                          │
# │             "mst_total_length": 45.4940483864837,                                                               │
# │             "entropy_distance_matrix": 2.742171248293366                                                        │
# │         },                                                                                                      │
# │         {                                                                                                       │
# │             "instance_id": 400,                                                                                 │
# │             "nr_cities": 30,                                                                                    │
# │             "nr_salesmen": 2,                                                                                   │
# │             "average_distance": 11.23831906953692,                                                              │
# │             "stddev_distance": 5.266772652080383,                                                               │
# │             "density": 0.028095797673842304,                                                                    │
# │             "salesmen_ratio": 0.06666666666666667,                                                              │
# │             "bounding_box_area": 400.0,                                                                         │
# │             "aspect_ratio": 1.0,                                                                                │
# │             "spread": 2.3356526304689593,                                                                       │
# │             "cluster_compactness": 0.3746106356512307,                                                          │
# │             "mst_total_length": 78.8816912603568,                                                               │
# │             "entropy_distance_matrix": 2.787971139716243                                                        │
# │         },                                                                                                      │
# │         {                                                                                                       │
# │             "instance_id": 649,                                                                                 │
# │             "nr_cities": 50,                                                                                    │
# │             "nr_salesmen": 10,                                                                                  │
# │             "average_distance": 53.1614665545729,                                                               │
# │             "stddev_distance": 24.808403921646583,                                                              │
# │             "density": 0.005712601177151611,                                                                    │
# │             "salesmen_ratio": 0.2,                                                                              │
# │             "bounding_box_area": 9306.0,                                                                        │
# │             "aspect_ratio": 0.9494949494949495,                                                                 │
# │             "spread": 2.3011313403824176,                                                                       │
# │             "cluster_compactness": 1.063229331091458,                                                           │
# │             "mst_total_length": 483.0538060264573,                                                              │
# │             "entropy_distance_matrix": 2.796910646144462                                                        │
# │         },                                                                                                      │
# │         {                                                                                                       │
# ...
# │     6. Branch and Cut and Ant Colony have a 20 seconds time limit, so they may output a weaker solution if the  │
# │ time limit is reached or even no solution at all.                                                               │
# │                                                                                                                 │
# │     Output your recommendations in the following format as in a CSV file:                                       │
# │     instance_id,predicted_algorithm                                                                             │
# │     where:                                                                                                      │
# │     - instance_id is the ID of the test instance                                                                │
# │     - predicted_algorithm is the algorithm you recommend for that instance                                      │
# │                                                                                                                 │
# ╰─ LiteLLMModel - llama-3.3-70b-versatile ────────────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
# Error in generating model output:
# litellm.RateLimitError: RateLimitError: GroqException - {"error":{"message":"Request too large for model
# `llama-3.3-70b-versatile` in organization `org_01jqy00a9ffc4r88wt8avqh336` service tier `on_demand` on tokens per
# minute (TPM): Limit 12000, Requested 28426, please reduce your message size and try again. Need more tokens?
# Upgrade to Dev Tier today at
# https://console.groq.com/settings/billing","type":"tokens","code":"rate_limit_exceeded"}}
# [Step 1: Duration 0.62 seconds]
# ---------------------------------------------------------------------------
# HTTPStatusError                           Traceback (most recent call last)
# File c:\Users\ignat\AppData\Local\Programs\Python\Python312\Lib\site-packages\litellm\llms\openai_like\chat\handler.py:372, in OpenAILikeChatHandler.completion(self, model, messages, api_base, custom_llm_provider, custom_prompt_dict, model_response, print_verbose, encoding, api_key, logging_obj, optional_params, acompletion, litellm_params, logger_fn, headers, timeout, client, custom_endpoint, streaming_decoder, fake_stream)
#     371 try:
# --> 372     response = client.post(
#     373         url=api_base, headers=headers, data=json.dumps(data)
#     374     )
#     375     response.raise_for_status()
#
# File c:\Users\ignat\AppData\Local\Programs\Python\Python312\Lib\site-packages\litellm\llms\custom_httpx\http_handler.py:577, in HTTPHandler.post(self, url, data, json, params, headers, stream, timeout, files, content, logging_obj)
#     575     setattr(e, "status_code", e.response.status_code)
# --> 577     raise e
#     578 except Exception as e:
#
# File c:\Users\ignat\AppData\Local\Programs\Python\Python312\Lib\site-packages\litellm\llms\custom_httpx\http_handler.py:558, in HTTPHandler.post(self, url, data, json, params, headers, stream, timeout, files, content, logging_obj)
#     557 response = self.client.send(req, stream=stream)
# --> 558 response.raise_for_status()
#     559 return response
#
# File c:\Users\ignat\AppData\Local\Programs\Python\Python312\Lib\site-packages\httpx\_models.py:829, in Response.raise_for_status(self)
#     828 message = message.format(self, error_type=error_type)
# --> 829 raise HTTPStatusError(message, request=request, response=self)
#
# HTTPStatusError: Client error '413 Payload Too Large' for url 'https://api.groq.com/openai/v1/chat/completions'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/413
#
# During handling of the above exception, another exception occurred:
#
# OpenAILikeError                           Traceback (most recent call last)
# File c:\Users\ignat\AppData\Local\Programs\Python\Python312\Lib\site-packages\litellm\main.py:1602, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, deployment_id, extra_headers, functions, function_call, base_url, api_version, api_key, model_list, thinking, **kwargs)
#    1600             optional_params[k] = v
# -> 1602     response = groq_chat_completions.completion(
#    1603         model=model,
#    1604         messages=messages,
#    1605         headers=headers,
#    1606         model_response=model_response,
#    1607         print_verbose=print_verbose,
#    1608         api_key=api_key,
#    1609         api_base=api_base,
#    1610         acompletion=acompletion,
#    1611         logging_obj=logging,
#    1612         optional_params=optional_params,
#    1613         litellm_params=litellm_params,
#    1614         logger_fn=logger_fn,
#    1615         timeout=timeout,  # type: ignore
#    1616         custom_prompt_dict=custom_prompt_dict,
#    1617         client=client,  # pass AsyncOpenAI, OpenAI client
#    1618         custom_llm_provider=custom_llm_provider,
#    1619         encoding=encoding,
#    1620     )
#    1621 elif custom_llm_provider == "aiohttp_openai":
#    1622     # NEW aiohttp provider for 10-100x higher RPS
#
# File c:\Users\ignat\AppData\Local\Programs\Python\Python312\Lib\site-packages\litellm\llms\groq\chat\handler.py:55, in GroqChatCompletion.completion(self, model, messages, api_base, custom_llm_provider, custom_prompt_dict, model_response, print_verbose, encoding, api_key, logging_obj, optional_params, acompletion, litellm_params, logger_fn, headers, timeout, client, custom_endpoint, streaming_decoder, fake_stream)
#      53     fake_stream = False
# ---> 55 return super().completion(
#      56     model=model,
#      57     messages=messages,
#      58     api_base=api_base,
#      59     custom_llm_provider=custom_llm_provider,
#      60     custom_prompt_dict=custom_prompt_dict,
#      61     model_response=model_response,
#      62     print_verbose=print_verbose,
#      63     encoding=encoding,
#      64     api_key=api_key,
#      65     logging_obj=logging_obj,
#      66     optional_params=optional_params,
#      67     acompletion=acompletion,
#      68     litellm_params=litellm_params,
#      69     logger_fn=logger_fn,
#      70     headers=headers,
#      71     timeout=timeout,
#      72     client=client,
#      73     custom_endpoint=custom_endpoint,
#      74     streaming_decoder=streaming_decoder,
#      75     fake_stream=fake_stream,
#      76 )
#
# File c:\Users\ignat\AppData\Local\Programs\Python\Python312\Lib\site-packages\litellm\llms\openai_like\chat\handler.py:378, in OpenAILikeChatHandler.completion(self, model, messages, api_base, custom_llm_provider, custom_prompt_dict, model_response, print_verbose, encoding, api_key, logging_obj, optional_params, acompletion, litellm_params, logger_fn, headers, timeout, client, custom_endpoint, streaming_decoder, fake_stream)
#     377 except httpx.HTTPStatusError as e:
# --> 378     raise OpenAILikeError(
#     379         status_code=e.response.status_code,
#     380         message=e.response.text,
#     381     )
#     382 except httpx.TimeoutException:
#
# OpenAILikeError: {"error":{"message":"Request too large for model `llama-3.3-70b-versatile` in organization `org_01jqy00a9ffc4r88wt8avqh336` service tier `on_demand` on tokens per minute (TPM): Limit 12000, Requested 28426, please reduce your message size and try again. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing","type":"tokens","code":"rate_limit_exceeded"}}
#
#
# During handling of the above exception, another exception occurred:
#
# RateLimitError                            Traceback (most recent call last)
# File c:\Users\ignat\AppData\Local\Programs\Python\Python312\Lib\site-packages\smolagents\agents.py:1225, in CodeAgent.step(self, memory_step)
#    1224 additional_args = {"grammar": self.grammar} if self.grammar is not None else {}
# -> 1225 chat_message: ChatMessage = self.model(
#    1226     self.input_messages,
#    1227     stop_sequences=["<end_code>", "Observation:", "Calling tools:"],
#    1228     **additional_args,
#    1229 )
#    1230 memory_step.model_output_message = chat_message
#
# File c:\Users\ignat\AppData\Local\Programs\Python\Python312\Lib\site-packages\smolagents\models.py:910, in LiteLLMModel.__call__(self, messages, stop_sequences, grammar, tools_to_call_from, **kwargs)
#     897 completion_kwargs = self._prepare_completion_kwargs(
#     898     messages=messages,
#     899     stop_sequences=stop_sequences,
#    (...)    907     **kwargs,
#     908 )
# --> 910 response = self.client.completion(**completion_kwargs)
#     912 self.last_input_token_count = response.usage.prompt_tokens
#
# File c:\Users\ignat\AppData\Local\Programs\Python\Python312\Lib\site-packages\litellm\utils.py:1234, in client.<locals>.wrapper(*args, **kwargs)
#    1231     logging_obj.failure_handler(
#    1232         e, traceback_exception, start_time, end_time
#    1233     )  # DO NOT MAKE THREADED - router retry fallback relies on this!
# -> 1234 raise e
#
# File c:\Users\ignat\AppData\Local\Programs\Python\Python312\Lib\site-packages\litellm\utils.py:1112, in client.<locals>.wrapper(*args, **kwargs)
#    1111 # MODEL CALL
# -> 1112 result = original_function(*args, **kwargs)
#    1113 end_time = datetime.datetime.now()
#
# File c:\Users\ignat\AppData\Local\Programs\Python\Python312\Lib\site-packages\litellm\main.py:3149, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, deployment_id, extra_headers, functions, function_call, base_url, api_version, api_key, model_list, thinking, **kwargs)
#    3147 except Exception as e:
#    3148     ## Map to OpenAI Exception
# -> 3149     raise exception_type(
#    3150         model=model,
#    3151         custom_llm_provider=custom_llm_provider,
#    3152         original_exception=e,
#    3153         completion_kwargs=args,
#    3154         extra_kwargs=kwargs,
#    3155     )
#
# File c:\Users\ignat\AppData\Local\Programs\Python\Python312\Lib\site-packages\litellm\litellm_core_utils\exception_mapping_utils.py:2214, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#    2213     setattr(e, "litellm_response_headers", litellm_response_headers)
# -> 2214     raise e
#    2215 else:
#
# File c:\Users\ignat\AppData\Local\Programs\Python\Python312\Lib\site-packages\litellm\litellm_core_utils\exception_mapping_utils.py:348, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#     347     exception_mapping_worked = True
# --> 348     raise RateLimitError(
#     349         message=f"RateLimitError: {exception_provider} - {message}",
#     350         model=model,
#     351         llm_provider=custom_llm_provider,
#     352         response=getattr(original_exception, "response", None),
#     353         litellm_debug_info=extra_information,
#     354     )
#     355 elif (
#     356     "The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     357     in error_str
#     358 ):
#
# RateLimitError: litellm.RateLimitError: RateLimitError: GroqException - {"error":{"message":"Request too large for model `llama-3.3-70b-versatile` in organization `org_01jqy00a9ffc4r88wt8avqh336` service tier `on_demand` on tokens per minute (TPM): Limit 12000, Requested 28426, please reduce your message size and try again. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing","type":"tokens","code":"rate_limit_exceeded"}}
#
#
# The above exception was the direct cause of the following exception:
#
# AgentGenerationError                      Traceback (most recent call last)
# Cell In[7], line 177
#     174     response = agent.run(task)
#     175     print(response)
# --> 177 choose_best_algorithm(train_db_file="../train_mTSP.sqlite3", test_db_file="../test_mTSP.sqlite3")
#
# Cell In[7], line 174, in choose_best_algorithm(train_db_file, test_db_file)
#     139 # {data_str}
#     140
#     141 # Task for the agent
#     142 task = f"""
#     143 You are an AI agent tasked with selecting the best algorithm for solving each instance of the mTSP problem.
#     144 Below is the data from the training instances and their results for different strategies:
#    (...)    171 - predicted_algorithm is the algorithm you recommend for that instance
#     172 """
# --> 174 response = agent.run(task)
#     175 print(response)
#
# File c:\Users\ignat\AppData\Local\Programs\Python\Python312\Lib\site-packages\smolagents\agents.py:332, in MultiStepAgent.run(self, task, stream, reset, images, additional_args, max_steps)
#     330     return self._run(task=self.task, max_steps=max_steps, images=images)
#     331 # Outputs are returned only at the end. We only look at the last step.
# --> 332 return deque(self._run(task=self.task, max_steps=max_steps, images=images), maxlen=1)[0].final_answer
#
# File c:\Users\ignat\AppData\Local\Programs\Python\Python312\Lib\site-packages\smolagents\agents.py:356, in MultiStepAgent._run(self, task, max_steps, images)
#     353     final_answer = self._execute_step(task, action_step)
#     354 except AgentGenerationError as e:
#     355     # Agent generation errors are not caused by a Model error but an implementation error: so we should raise them and exit.
# --> 356     raise e
#     357 except AgentError as e:
#     358     # Other AgentError types are caused by the Model, so we should log them and iterate.
#     359     action_step.error = e
#
# File c:\Users\ignat\AppData\Local\Programs\Python\Python312\Lib\site-packages\smolagents\agents.py:353, in MultiStepAgent._run(self, task, max_steps, images)
#     351 action_step = self._create_action_step(step_start_time, images)
#     352 try:
# --> 353     final_answer = self._execute_step(task, action_step)
#     354 except AgentGenerationError as e:
#     355     # Agent generation errors are not caused by a Model error but an implementation error: so we should raise them and exit.
#     356     raise e
#
# File c:\Users\ignat\AppData\Local\Programs\Python\Python312\Lib\site-packages\smolagents\agents.py:376, in MultiStepAgent._execute_step(self, task, memory_step)
#     374 def _execute_step(self, task: str, memory_step: ActionStep) -> Union[None, Any]:
#     375     self.logger.log_rule(f"Step {self.step_number}", level=LogLevel.INFO)
# --> 376     final_answer = self.step(memory_step)
#     377     if final_answer is not None and self.final_answer_checks:
#     378         self._validate_final_answer(final_answer)
#
# File c:\Users\ignat\AppData\Local\Programs\Python\Python312\Lib\site-packages\smolagents\agents.py:1241, in CodeAgent.step(self, memory_step)
#    1239     memory_step.model_output = model_output
#    1240 except Exception as e:
# -> 1241     raise AgentGenerationError(f"Error in generating model output:\n{e}", self.logger) from e
#    1243 self.logger.log_markdown(
#    1244     content=model_output,
#    1245     title="Output message of the LLM:",
#    1246     level=LogLevel.DEBUG,
#    1247 )
#    1249 # Parse
#
# AgentGenerationError: Error in generating model output:
# litellm.RateLimitError: RateLimitError: GroqException - {"error":{"message":"Request too large for model `llama-3.3-70b-versatile` in organization `org_01jqy00a9ffc4r88wt8avqh336` service tier `on_demand` on tokens per minute (TPM): Limit 12000, Requested 28426, please reduce your message size and try again. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing","type":"tokens","code":"rate_limit_exceeded"}}
